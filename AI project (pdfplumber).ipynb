# %%
pip install pdfplumber
# Out:
# ...
#    ---------------------------------------- 0.0/6.6 MB ? eta -:--:--
#    --- ------------------------------------ 0.5/6.6 MB 2.1 MB/s eta 0:00:03
#    ------- -------------------------------- 1.3/6.6 MB 3.4 MB/s eta 0:00:02
#    ----------- ---------------------------- 1.8/6.6 MB 3.0 MB/s eta 0:00:02
#    -------------- ------------------------- 2.4/6.6 MB 3.1 MB/s eta 0:00:02
#    ------------------- -------------------- 3.1/6.6 MB 3.0 MB/s eta 0:00:02
#    ---------------------- ----------------- 3.7/6.6 MB 2.9 MB/s eta 0:00:02
#    ------------------------- -------------- 4.2/6.6 MB 2.8 MB/s eta 0:00:01
#    ------------------------- -------------- 4.2/6.6 MB 2.8 MB/s eta 0:00:01
#    --------------------------- ------------ 4.5/6.6 MB 2.5 MB/s eta 0:00:01
#    ------------------------------- -------- 5.2/6.6 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------- ----- 5.8/6.6 MB 2.6 MB/s eta 0:00:01
# ...

# %%
from llama_index.llms.groq import Groq
import pdfplumber

# %%
api_key="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"
llm = Groq(model="llama-3.3-70b-versatile", api_key=api_key)

# %%
def extract_text_with_pdfplumber(pdf_path):
    text = ""
    with pdfplumber.open(pdf_path) as pdf:
        for page in pdf.pages:
            text += page.extract_text()
    return text

# Example usage
#pdf_path = "/content/Profile.pdf"  # Replace with the path to your PDF file
extracted_text = extract_text_with_pdfplumber("Resume_data_analyst_experienced.pdf")
print(extracted_text)
# Out:
# Dhaval Patel
# Phone: (123)-456-7890 | github.com/dhavalsays | ABC@GMAIL.COM
# ​ ​
# Senior data analyst with 5 years of data analysis experience in healthcare and finance industry.
# ​ ​
# Proven track record of analysis huge volume of data to gain business insights using python, apache
# hadoop and tableau
# Skills
# Programming Python, R, SQL, Excel VBA Macros
# Visualization Tableau, Power BI, Excel Charts, Jupyter Notebook
# Database SAP S/4 HANA, MySQL, Apache Hadoop
# Soft Skills Excellent verbal and written communication skills, presentation and
# negotiation skills
# Certifications and Awards
# - IBM professional data science certification
# - Won best analyst award for exceptional work in classification of healthcare documents
# (Mobility Health Services Ltd - June 2019)
# - Contributed to pandas open source (3 PRs accepted)
# Experience
# Feb 2018 - PRESENT
# Mobility Health Services Ltd, Delhi - Data Analyst
# ​
# ...

# %%
def summarize_text(text):
    response = llm.complete(f"Summarize the text in the perspetive of a recruiter: {text}")
    return response

# Example usage
summary = summarize_text(extracted_text)
print("Summary:")
print(summary)
# Out:
# Summary:
# **Candidate Summary: Dhaval Patel**
#
# As a recruiter, I am impressed with Dhaval Patel's profile, which showcases his strong background in data analysis, particularly in the healthcare and finance industries. With 5 years of experience, Dhaval has developed a robust skill set in programming languages such as Python, R, and SQL, as well as data visualization tools like Tableau and Power BI.
#
# **Key Strengths:**
#
# 1. **Data Analysis**: Dhaval has a proven track record of analyzing large volumes of data to gain business insights, using tools like Python, Apache Hadoop, and Tableau.
# 2. **Technical Skills**: He possesses a strong foundation in programming languages, data visualization, and database management, including SAP S/4 HANA, MySQL, and Apache Hadoop.
# 3. **Communication Skills**: Dhaval has excellent verbal and written communication skills, presentation, and negotiation skills, which are essential for effective collaboration with cross-functional teams.
# ...

# %%
def ask_question(text, question):
    response = llm.complete(f"Based on the following text: {text}, answer the question: {question}")
    return response

# Example usage
question = "What is Dhaval Patel qualification?"
answer = ask_question(extracted_text, question)
print(f"Question: {question}")
print(f"Answer: {answer}")
# Out:
# Question: What is Dhaval Patel qualification?
# Answer: Dhaval Patel's qualification is a Bachelor's degree in Economics and Statistics from Dharmsinh Desai University, Ahmedabad, with a GPA of 3.7. Additionally, he holds an IBM Professional Data Science certification.
